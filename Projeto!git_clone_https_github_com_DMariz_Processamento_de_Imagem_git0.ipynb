# %% [markdown]
# <a href="https://colab.research.google.com/github/DMariz/Processamento_de_Imagem/blob/master/Projeto!git_clone_https_github_com_DMariz_Processamento_de_Imagem_git0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importação
# POR FAVOR RODE AS COISAS EM SEQUÊNCIA
#
# Não saia da se quencia correta

# %%
# !git clone https://github.com/DMariz/Processamento_de_Imagem.git
# Out:
# Cloning into 'Processamento_de_Imagem'...
# remote: Enumerating objects: 301, done.
# remote: Total 301 (delta 0), reused 0 (delta 0), pack-reused 301
# Receiving objects: 100% (301/301), 2.91 MiB | 3.23 MiB/s, done.
# Resolving deltas: 100% (104/104), done.

# %%
import cv2
import numpy as np
import os

# %matplotlib inline
from matplotlib import pyplot as plt
from google.colab.patches import cv2_imshow  #usar o comando imshow diretamente no colab

####### LENDO IMAGENS

img1 = cv2.imread('Processamento_de_Imagem/Mamografias/mdb001.bmp')
img2 = cv2.imread('Processamento_de_Imagem/Mamografias/mdb005.bmp')
img3 = cv2.imread('Processamento_de_Imagem/Mamografias/mdb010.bmp')
img4 = cv2.imread('Processamento_de_Imagem/Mamografias/mdb017.bmp')
img5 = cv2.imread('Processamento_de_Imagem/Mamografias/mdb021.bmp')

# %% [markdown]
# ## Tentando montar ou Salvar arquivos

# %% [markdown]
# GIT NÃO PEGA DIREITO. VAMOS USAR O GOOGLE DRIVE MESMO
# Diretório =  'drive/My Drive/Colab Notebooks'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **Sobre esse projeto**
# Aplicando o conhecimento de processamento de imagens
#
# Utilizando a monografia de Thays Ferreira da Silva(Análise de Descritores de Imagem e Classificadores APlicados para Detecção de Lesõoes em imagens de Mamografia Digital , 2017 Recife) como base de estudo para realizar operações aprendidas em aula.

# %% [markdown]
# # PRÉ - PROCESSAMENTO
#
# O objetivo e utilizar o aprimoramento de imagem é para transformar a imagem mais adequada
# a outros processamentos de imagens, como melhor visualização de características ou restaurar imagens que foram deterioradas. A finalidade da manipulação de contraste é melhorar a visualização de contraste geral da imagem, destacar as regiões de baixa intensidade, melhorando a leitura
# da imagem.

# %% [markdown]
# ## Equalização do Histograma (HE)
#
# Na equalização do histograma (HE) os valores de intensidade da imagem são
# redistribuídos para aperfeiçoar o contraste. HE remapeia os tons de cinza de uma imagem baseada na probabilidade de distribuição dos nos níveis de cinza dados
#
# Esse método é uma operação global, e não
# preserva a iluminação da imagem. HE é amplamente utilizado em processamento de
# imagens médicas, imagens de radar e outros

# %%
print(img1.shape)

#plt.figure(figsize=(7, 6), dpi= 80, facecolor='w', edgecolor='k')
#plt.axis("off")
#plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB)) #Conversão necessária para protar a imagem, devido ao opencv usa o
                                                 #formato RGB, enquanto o matplotlib usa RGB

imggray1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
imggray2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)
imggray3 = cv2.cvtColor(img3, cv2.COLOR_BGR2GRAY)
imggray4 = cv2.cvtColor(img4, cv2.COLOR_BGR2GRAY)
imggray5 = cv2.cvtColor(img5, cv2.COLOR_BGR2GRAY)

equ1 = cv2.equalizeHist(imggray1)
equ2 = cv2.equalizeHist(imggray2)
equ3 = cv2.equalizeHist(imggray3)
equ4 = cv2.equalizeHist(imggray4)
equ5 = cv2.equalizeHist(imggray5)


fig, axes = plt.subplots(1, 5, figsize=(20, 20))
ax = axes.ravel()
#Original 1
ax[0].imshow(imggray1, cmap='gray')
ax[0].set_title('original 1')
ax[0].set_axis_off()

#Original 2
ax[1].imshow(imggray2, cmap='gray')
ax[1].set_title('original 2')
ax[1].set_axis_off()

#Original 3
ax[2].imshow(imggray3, cmap='gray')
ax[2].set_title('original 3')
ax[2].set_axis_off()

#Original 4
ax[3].imshow(imggray4, cmap='gray')
ax[3].set_title('original 4')
ax[3].set_axis_off()

#Original 5
ax[4].imshow(imggray5, cmap='gray')
ax[4].set_title('original 5')
ax[4].set_axis_off()

fig, axes = plt.subplots(1, 5, figsize=(20, 20))
ax = axes.ravel()
#Equalizada 1
ax[0].imshow(equ1, cmap='gray')
ax[0].set_title('Equalizada 1')
ax[0].set_axis_off()
#Equalizada 2
ax[1].imshow(equ2, cmap='gray')
ax[1].set_title('Equalizada 2')
ax[1].set_axis_off()
#Equalizada 3
ax[2].imshow(equ3, cmap='gray')
ax[2].set_title('Equalizada 3')
ax[2].set_axis_off()
#Equalizada 4
ax[3].imshow(equ4, cmap='gray')
ax[3].set_title('Equalizada 4')
ax[3].set_axis_off()
#Equalizada 5
ax[4].imshow(equ5, cmap='gray')
ax[4].set_title('Equalizada 5')
ax[4].set_axis_off()
# Out:
# (531, 423, 3)

# %% [markdown]
# ## Sobel
# É um dos filtros mais populares passa - alta
#
# O filtro Sobel (ou operador sobel) auxilia na detecção de bordas e transição
# de imagens. O operador sobel utiliza dois kernels, um para modificação horizontal e
# outra para modificação vertical. Seus kernels não possuem foco no pixel atual, mas
# nos pixels vizinhos.
#
# Ele coloca mais em destaque as alterações de dinâmicas

# %%
imggray = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)

sobelx = cv2.Sobel(imggray,cv2.CV_64F,1,0,ksize=5)
sobely = cv2.Sobel(imggray,cv2.CV_64F,0,1,ksize=5)
sobelxy = cv2.cv2.bitwise_and(sobelx,sobely) #APLICANDO O AND

#kerne
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
ax = axes.ravel()

ax[0].imshow(sobelx, cmap='gray')
ax[0].set_title('Sobel x')
ax[0].set_axis_off()

ax[1].imshow(sobely, cmap='gray')
ax[1].set_title('Sobel y')
ax[1].set_axis_off()

ax[2].imshow(sobelxy, cmap='gray')
ax[2].set_title('uniao Sobel x e Sobel y')
ax[2].set_axis_off()

# %% [markdown]
# ## CLAHE

# %%
# convert image to LAB color model
image_lab = cv2.cvtColor(img3, cv2.COLOR_BGR2LAB)

# split the image into L, A, and B channels
l_channel, a_channel, b_channel = cv2.split(image_lab)

# apply CLAHE to lightness channel
clahe = cv2.createCLAHE(clipLimit= 2, tileGridSize=(16, 16))
cl = clahe.apply(l_channel)

# merge the CLAHE enhanced L channel with the original A and B channel
merged_channels = cv2.merge((cl, a_channel, b_channel))


fig, axes = plt.subplots(1, 2, figsize=(10, 5))
ax = axes.ravel()

ax[0].imshow(img3, cmap='gray')
ax[0].set_title('Original')
ax[0].set_axis_off()


ax[1].imshow(cl, cmap='gray')
ax[1].set_title('CLAHE')
ax[1].set_axis_off()

# %% [markdown]
# ## CLAHE + HE
#
# Seguindo de acordo com a metodologia de Thays, ela concluiu que CLAHE+HE é a  melhor aperfeiçoamento da imagem para ajudar na detecção de pontos.

# %%
clhe = cv2.equalizeHist(cl) #aplicando o HE no Clahe


fig, axes = plt.subplots(1, 2, figsize=(10, 5))
ax = axes.ravel()

ax[0].imshow(cl, cmap='gray')
ax[0].set_title('CLAHE')
ax[0].set_axis_off()

ax[1].imshow(clhe, cmap='gray')
ax[1].set_title('CLAHE + HE')
ax[1].set_axis_off()

# %% [markdown]
# # SEGMENTAÇÃO

# %% [markdown]
# ## Meanshift

# %%
clhe_cor =  cv2.cvtColor(clhe,cv2.COLOR_GRAY2BGR) # Colocando os 3 canais de cores para aplicar o meanshift


img = cv2.imread('Processamento_de_Imagem/Mamografias/mdb017.bmp') #Lendo uma imagem

meanshift = cv2.pyrMeanShiftFiltering(clhe_cor, sp=15, sr=20, maxLevel=1, termcrit=(cv2.TERM_CRITERIA_EPS+cv2.TERM_CRITERIA_MAX_ITER, 5, 1))
fig, axes = plt.subplots(1, 2, figsize=(15, 8))
ax = axes.ravel()

ax[0].imshow(clhe, cmap='gray')
ax[0].set_title('clhe_eq')
ax[0].set_axis_off()

ax[1].imshow(cv2.cvtColor(meanshift, cv2.COLOR_BGR2RGB))#convertendo para RGB antes de plotar
ax[1].set_title('MeanShift')
ax[1].set_axis_off()

# %% [markdown]
# ## k-MEANS CLUSTERING

# %%
img2 = meanshift.copy() #cv2.imread('processamento_imagens/imagens/pudimcat.jpg')
Z = img2.reshape((-1,3))

# convert to np.float32
Z = np.float32(Z)

# define criteria, number of clusters(K) and apply kmeans()
criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 10, 1.0)
K = 3
ret,label,center=cv2.kmeans(Z,K,None,criteria,10,cv2.KMEANS_RANDOM_CENTERS)

# Now convert back into uint8, and make original image
center = np.uint8(center)
res = center[label.flatten()]
res2 = res.reshape((img2.shape))

fig, axes = plt.subplots(1, 2, figsize=(15, 8))
ax = axes.ravel()

ax[0].imshow(cv2.cvtColor(img2, cv2.COLOR_BGR2RGB))
ax[0].set_title('Original')
ax[0].set_axis_off()

ax[1].imshow(cv2.cvtColor(res2, cv2.COLOR_BGR2RGB))
ax[1].set_title('k-means clustering')
ax[1].set_axis_off()

# %% [markdown]
# ## Watershed

# %%
img3= res2.copy()
#img3 = meanshift.copy()
img3c = img3.copy()
gray = cv2.cvtColor(img3,cv2.COLOR_BGR2GRAY)
ret, thresh = cv2.threshold(gray,0,255,cv2.THRESH_BINARY_INV+cv2.THRESH_OTSU)

# remove ruídos
kernel = np.ones((3,3),np.uint8)
opening = cv2.morphologyEx(thresh,cv2.MORPH_OPEN,kernel, iterations = 0)

# Fundo da imagem
sure_bg = cv2.dilate(opening,kernel,iterations=3)

# Objetos da imagem
dist_transform = cv2.distanceTransform(opening,cv2.DIST_L2,5)
ret, sure_fg = cv2.threshold(dist_transform,0.7*dist_transform.max(),255,0)

# Encontrando regiões desconhecidas
sure_fg = np.uint8(sure_fg)
unknown = cv2.subtract(sure_bg,sure_fg)

# Rotulando a imagem
ret, markers = cv2.connectedComponents(sure_fg)

# Marca os objetos
markers = markers+1

# Regiões desconhecidas serão 0
markers[unknown==255] = 0

markers = cv2.watershed(img3,markers)
img3[markers == -1] = [255,0,0]

fig, axes = plt.subplots(1, 2, figsize=(12, 8))
ax = axes.ravel()

ax[0].imshow(opening, cmap='gray')
ax[0].set_title('Imagem Binária')
ax[0].set_axis_off()

ax[1].imshow(markers, cmap='gray')
ax[1].set_title('watershed')
ax[1].set_axis_off()

fig, axes = plt.subplots(1, 2, figsize=(12, 8))
ax = axes.ravel()

ax[0].imshow(cv2.cvtColor(img3c, cv2.COLOR_BGR2RGB))
ax[0].set_title('Original')
ax[0].set_axis_off()

ax[1].imshow(cv2.cvtColor(img3, cv2.COLOR_BGR2RGB))
ax[1].set_title('watershed')
ax[1].set_axis_off()

# %% [markdown]
# # DESCRITORES DE TEXTURA

# %% [markdown]
# ## LBP

# %%
def get_pixel(img, center, x, y):
    new_value = 0
    try:
        if img[x][y] >= center:
            new_value = 1
    except:
        pass
    return new_value

def lbp_calculated_pixel(img, x, y):
    '''
     64 | 128 |   1
    ----------------
     32 |   0 |   2
    ----------------
     16 |   8 |   4
    '''
    center = img[x][y]
    val_ar = []
    val_ar.append(get_pixel(img, center, x-1, y+1))     # top_right
    val_ar.append(get_pixel(img, center, x, y+1))       # right
    val_ar.append(get_pixel(img, center, x+1, y+1))     # bottom_right
    val_ar.append(get_pixel(img, center, x+1, y))       # bottom
    val_ar.append(get_pixel(img, center, x+1, y-1))     # bottom_left
    val_ar.append(get_pixel(img, center, x, y-1))       # left
    val_ar.append(get_pixel(img, center, x-1, y-1))     # top_left
    val_ar.append(get_pixel(img, center, x-1, y))       # top

    power_val = [1, 2, 4, 8, 16, 32, 64, 128] # VALORAÇÃO
    val = 0
    for i in range(len(val_ar)):
        val += val_ar[i] * power_val[i]
    return val     # quanto esse pixel "vale" e onde via entrar no histograma

############################################################

height, width, channel = img1.shape
img_gray = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
img_lbp = np.zeros((height, width,3), np.uint8)

for i in range(0, height):
  for j in range(0, width):
    img_lbp[i, j] = lbp_calculated_pixel(img_gray, i, j) ## CALCULA O LBP

  hist_lbp = cv2.calcHist([img_lbp], [0], None, [256], [0, 256])  ## HISTOGRAMA

fig, axes = plt.subplots(1, 2, figsize=(12, 8))
ax = axes.ravel()

ax[0].imshow(img1, cmap='gray')
ax[0].set_title('Original')
ax[0].set_axis_off()

ax[1].imshow(img_lbp, cmap='gray')
ax[1].set_title('LBP')
ax[1].set_axis_off()

'''plt.hist(img_lbp.ravel(),256,[0,256]);
plt.show()'''
# Out:
# 'plt.hist(img_lbp.ravel(),256,[0,256]); \nplt.show()'

# %% [markdown]
# ##LBP no Sobel

# %%
height, width = sobely.shape
#img_gray = cv2.cvtColor(clhe, cv2.COLOR_BGR2GRAY)
img_lbp = np.zeros((height, width,3), np.uint8)

for i in range(0, height):
  for j in range(0, width):
    img_lbp[i, j] = lbp_calculated_pixel(sobely, i, j)


fig, axes = plt.subplots(1, 2, figsize=(12, 8))
ax = axes.ravel()

ax[0].imshow(sobely, cmap='gray')
ax[0].set_title('Sobel em Y')
ax[0].set_axis_off()

ax[1].imshow(img_lbp, cmap='gray')
ax[1].set_title('LBP')
ax[1].set_axis_off()

# %% [markdown]
# # SALVANDO NO DRIVE

# %%
# %cd '/content'
bancoimagens = os.listdir('Processamento_de_Imagem/Mamografias') # Vetor que salva todas imagens dentro do diretorio
# Out:
# /content

# %% [markdown]
# ##Salvando Equalização do histograma

# %%
for arquivo in bancoimagens:                             # pecorre o vetor de imagens do diretorio

    #print('>>>Caminho da imagem Encontrado !!')




    diretorio= "Processamento_de_Imagem/Mamografias/%s"%(arquivo)    # diretorio da imagem atual
    #print(diretorio)

    # %cd /content
    img = cv2.imread(diretorio)                                      # Lê imagem atual

    tgray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    equ1 = cv2.equalizeHist(tgray)                                   #Aplica a equalização do Histograma


    nomedoarquivo = ('%s_equalizado.jpg' %(arquivo))
    # %cd '/content/drive/My Drive/Colab Notebooks/Processadas/Equalizacao'

    cv2.imwrite(nomedoarquivo, equ1)                                       #Escreve a imagem PROCESSADA no drive
    print('>>>foi Salvo com nome %s!!' %(nomedoarquivo))
# Out:
# /content
# [Errno 2] No such file or directory: '/content/drive/My Drive/Colab Notebooks/Processadas/Equalizacao'
# /content
# >>>foi Salvo com nome mdb144_2.bmp_equalizado.jpg!!
# /content
# [Errno 2] No such file or directory: '/content/drive/My Drive/Colab Notebooks/Processadas/Equalizacao'
# /content
# >>>foi Salvo com nome mdb204.bmp_equalizado.jpg!!
# /content
# [Errno 2] No such file or directory: '/content/drive/My Drive/Colab Notebooks/Processadas/Equalizacao'
# /content
# >>>foi Salvo com nome mdb063.bmp_equalizado.jpg!!
# /content
# [Errno 2] No such file or directory: '/content/drive/My Drive/Colab Notebooks/Processadas/Equalizacao'
# /content
# >>>foi Salvo com nome mdb202.bmp_equalizado.jpg!!
# /content
# [Errno 2] No such file or directory: '/content/drive/My Drive/Colab Notebooks/Processadas/Equalizacao'
# /content
# >>>foi Salvo com nome mdb069.bmp_equalizado.jpg!!
# /content
# ...

# %% [markdown]
# ##Salvando Sobel

# %%
for arquivo in bancoimagens:                                          # pecorre o vetor de imagens do diretorio

    #print('>>>Caminho da imagem Encontrado !!')

    diretorio= "Processamento_de_Imagem/Mamografias/%s"%(arquivo)     # diretorio vai receber o diretorio da imagem atual
    #print(diretorio)

    # %cd /content
    img = cv2.imread(diretorio)                                       # Lê imagem atual

    imggray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)


    sobelx = cv2.Sobel(imggray,cv2.CV_64F,1,0,ksize=5)
    sobely = cv2.Sobel(imggray,cv2.CV_64F,0,1,ksize=5)
    sobelxy = cv2.cv2.bitwise_and(sobelx,sobely)


    # %cd '/content/drive/My Drive/Colab Notebooks/Processadas/Sobel'


    nomedoarquivo = ('Sobelx%s.jpg' %(arquivo))
    cv2.imwrite(nomedoarquivo, sobelx)                                       #Escreve a imagem PROCESSADA no drive

    nomedoarquivo = ('Sobely%s.jpg' %(arquivo))
    cv2.imwrite(nomedoarquivo, sobely)

    nomedoarquivo = ('Sobelxy%s.jpg' %(arquivo))
    cv2.imwrite(nomedoarquivo, sobelxy)

    print('>>>foi Salvo com nome %s!!' %(nomedoarquivo))
# Out:
# /content
# [Errno 2] No such file or directory: '/content/drive/My Drive/Colab Notebooks/Processadas/Sobel'
# /content
# >>>foi Salvo com nome Sobelxymdb144_2.bmp.jpg!!
# /content
# [Errno 2] No such file or directory: '/content/drive/My Drive/Colab Notebooks/Processadas/Sobel'
# /content
# >>>foi Salvo com nome Sobelxymdb204.bmp.jpg!!
# /content
# [Errno 2] No such file or directory: '/content/drive/My Drive/Colab Notebooks/Processadas/Sobel'
# /content
# >>>foi Salvo com nome Sobelxymdb063.bmp.jpg!!
# /content
# [Errno 2] No such file or directory: '/content/drive/My Drive/Colab Notebooks/Processadas/Sobel'
# /content
# >>>foi Salvo com nome Sobelxymdb202.bmp.jpg!!
# /content
# [Errno 2] No such file or directory: '/content/drive/My Drive/Colab Notebooks/Processadas/Sobel'
# /content
# >>>foi Salvo com nome Sobelxymdb069.bmp.jpg!!
# /content
# [Errno 2] No such file or directory: '/content/drive/My Drive/Colab Notebooks/Processadas/Sobel'
# /content
# ...

# %% [markdown]
# ## Salvando CLAHE

# %%
for arquivo in bancoimagens:                                          # pecorre o vetor de imagens do diretorio

    #print('>>>Caminho da imagem Encontrado !!')

    diretorio= "Processamento_de_Imagem/Mamografias/%s"%(arquivo)     # diretorio vai receber o diretorio da imagem atual
    #print(diretorio)

    # %cd /content
    img = cv2.imread(diretorio)                                       # Lê imagem atual


    # convert image to LAB color model
    image_lab = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)

    # split the image into L, A, and B channels
    l_channel, a_channel, b_channel = cv2.split(image_lab)

    # apply CLAHE to lightness channel
    clahe = cv2.createCLAHE(clipLimit= 2, tileGridSize=(16, 16))
    cl = clahe.apply(l_channel)

    # merge the CLAHE enhanced L channel with the original A and B channel
    merged_channels = cv2.merge((cl, a_channel, b_channel))

    # %cd '/content/drive/My Drive/Colab Notebooks/Processadas/Clahe'


    nomedoarquivo = ('clahex%s.jpg' %(arquivo))
    cv2.imwrite(nomedoarquivo, cl)                                       #Escreve a imagem PROCESSADA no drive


    print('>>>foi Salvo com nome %s!!' %(nomedoarquivo))
# Out:
# /content
# [Errno 2] No such file or directory: '/content/drive/My Drive/Colab Notebooks/Processadas/Clahe'
# /content
# >>>foi Salvo com nome clahexmdb144_2.bmp.jpg!!
# /content
# [Errno 2] No such file or directory: '/content/drive/My Drive/Colab Notebooks/Processadas/Clahe'
# /content
# >>>foi Salvo com nome clahexmdb204.bmp.jpg!!
# /content
# [Errno 2] No such file or directory: '/content/drive/My Drive/Colab Notebooks/Processadas/Clahe'
# /content
# >>>foi Salvo com nome clahexmdb063.bmp.jpg!!
# /content
# [Errno 2] No such file or directory: '/content/drive/My Drive/Colab Notebooks/Processadas/Clahe'
# /content
# >>>foi Salvo com nome clahexmdb202.bmp.jpg!!
# /content
# [Errno 2] No such file or directory: '/content/drive/My Drive/Colab Notebooks/Processadas/Clahe'
# /content
# >>>foi Salvo com nome clahexmdb069.bmp.jpg!!
# /content
# [Errno 2] No such file or directory: '/content/drive/My Drive/Colab Notebooks/Processadas/Clahe'
# /content
# ...

# %% [markdown]
# ## Salvando Clahe + HE

# %%
for arquivo in bancoimagens:                                          # pecorre o vetor de imagens do diretorio

    #print('>>>Caminho da imagem Encontrado !!')

    diretorio= "Processamento_de_Imagem/Mamografias/%s"%(arquivo)     # diretorio vai receber o diretorio da imagem atual
    #print(diretorio)

    # %cd /content
    img = cv2.imread(diretorio)                                       # Lê imagem atual


    # convert image to LAB color model
    image_lab = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)

    # split the image into L, A, and B channels
    l_channel, a_channel, b_channel = cv2.split(image_lab)

    # apply CLAHE to lightness channel
    clahe = cv2.createCLAHE(clipLimit= 2, tileGridSize=(16, 16))
    cl = clahe.apply(l_channel)

    # merge the CLAHE enhanced L channel with the original A and B channel
    merged_channels = cv2.merge((cl, a_channel, b_channel))

    clhe = cv2.equalizeHist(cl) #aplicando o HE no Clahe
    # %cd '/content/drive/My Drive/Colab Notebooks/Processadas/Clahe_HE'


    nomedoarquivo = ('clahe_HE_x%s.jpg' %(arquivo))
    cv2.imwrite(nomedoarquivo, clhe)                                       #Escreve a imagem PROCESSADA no drive


    print('>>>foi Salvo com nome %s!!' %(nomedoarquivo))
# Out:
# /content
# [Errno 2] No such file or directory: '/content/drive/My Drive/Colab Notebooks/Processadas/Clahe_HE'
# /content
# >>>foi Salvo com nome clahe_HE_xmdb144_2.bmp.jpg!!
# /content
# [Errno 2] No such file or directory: '/content/drive/My Drive/Colab Notebooks/Processadas/Clahe_HE'
# /content
# >>>foi Salvo com nome clahe_HE_xmdb204.bmp.jpg!!
# /content
# [Errno 2] No such file or directory: '/content/drive/My Drive/Colab Notebooks/Processadas/Clahe_HE'
# /content
# >>>foi Salvo com nome clahe_HE_xmdb063.bmp.jpg!!
# /content
# [Errno 2] No such file or directory: '/content/drive/My Drive/Colab Notebooks/Processadas/Clahe_HE'
# /content
# >>>foi Salvo com nome clahe_HE_xmdb202.bmp.jpg!!
# /content
# [Errno 2] No such file or directory: '/content/drive/My Drive/Colab Notebooks/Processadas/Clahe_HE'
# /content
# >>>foi Salvo com nome clahe_HE_xmdb069.bmp.jpg!!
# /content
# [Errno 2] No such file or directory: '/content/drive/My Drive/Colab Notebooks/Processadas/Clahe_HE'
# ...

# %% [markdown]
# ##Salvando k-MEANS

# %%
for arquivo in bancoimagens:                                          # pecorre o vetor de imagens do diretorio

    #print('>>>Caminho da imagem Encontrado !!')

    diretorio= "Processamento_de_Imagem/Mamografias/%s"%(arquivo)     # diretorio vai receber o diretorio da imagem atual
    #print(diretorio)

    # %cd /content
    img = cv2.imread(diretorio)                                       # Lê imagem atual


    # convert image to LAB color model
    image_lab = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)

    # split the image into L, A, and B channels
    l_channel, a_channel, b_channel = cv2.split(image_lab)

    # apply CLAHE to lightness channel
    clahe = cv2.createCLAHE(clipLimit= 2, tileGridSize=(16, 16))
    cl = clahe.apply(l_channel)

    # merge the CLAHE enhanced L channel with the original A and B channel
    merged_channels = cv2.merge((cl, a_channel, b_channel))

    clhe = cv2.equalizeHist(cl) #aplicando o HE no Clahe
    gray = cv2.cvtColor(img3,cv2.COLOR_BGR2GRAY)
    ret, thresh = cv2.threshold(gray,0,255,cv2.THRESH_BINARY_INV+cv2.THRESH_OTSU)

    # remove ruídos
    kernel = np.ones((3,3),np.uint8)
    opening = cv2.morphologyEx(thresh,cv2.MORPH_OPEN,kernel, iterations = 0)

    # Fundo da imagem
    sure_bg = cv2.dilate(opening,kernel,iterations=3)

    # Objetos da imagem
    dist_transform = cv2.distanceTransform(opening,cv2.DIST_L2,5)
    ret, sure_fg = cv2.threshold(dist_transform,0.7*dist_transform.max(),255,0)

    # Encontrando regiões desconhecidas
    sure_fg = np.uint8(sure_fg)
    unknown = cv2.subtract(sure_bg,sure_fg)

    # Rotulando a imagem
    ret, markers = cv2.connectedComponents(sure_fg)

    # Marca os objetos
    markers = markers+1

    # Regiões desconhecidas serão 0
    markers[unknown==255] = 0

    markers = cv2.watershed(img3,markers)




    # %cd '/content/drive/My Drive/Colab Notebooks/Processadas/Clahe_HE'


    nomedoarquivo = ('clahe_HE_x%s.jpg' %(arquivo))
    cv2.imwrite(nomedoarquivo, clhe)                                       #Escreve a imagem PROCESSADA no drive


    print('>>>foi Salvo com nome %s!!' %(nomedoarquivo))
# Out:
# /content
# [Errno 2] No such file or directory: '/content/drive/My Drive/Colab Notebooks/Processadas/Clahe_HE'
# /content
# >>>foi Salvo com nome clahe_HE_xmdb144_2.bmp.jpg!!
# /content
# [Errno 2] No such file or directory: '/content/drive/My Drive/Colab Notebooks/Processadas/Clahe_HE'
# /content
# >>>foi Salvo com nome clahe_HE_xmdb204.bmp.jpg!!
# /content
# [Errno 2] No such file or directory: '/content/drive/My Drive/Colab Notebooks/Processadas/Clahe_HE'
# /content
# >>>foi Salvo com nome clahe_HE_xmdb063.bmp.jpg!!
# /content
# [Errno 2] No such file or directory: '/content/drive/My Drive/Colab Notebooks/Processadas/Clahe_HE'
# /content
# >>>foi Salvo com nome clahe_HE_xmdb202.bmp.jpg!!
# /content
# [Errno 2] No such file or directory: '/content/drive/My Drive/Colab Notebooks/Processadas/Clahe_HE'
# /content
# >>>foi Salvo com nome clahe_HE_xmdb069.bmp.jpg!!
# /content
# [Errno 2] No such file or directory: '/content/drive/My Drive/Colab Notebooks/Processadas/Clahe_HE'
# ...

# %% [markdown]
# ##Salvando o Watershad binar

# %%
for arquivo in bancoimagens:                                          # pecorre o vetor de imagens do diretorio

    #print('>>>Caminho da imagem Encontrado !!')

    diretorio= "Processamento_de_Imagem/Mamografias/%s"%(arquivo)     # diretorio vai receber o diretorio da imagem atual
    #print(diretorio)

    # %cd /content
    img = cv2.imread(diretorio)

    img3= res2.copy()
    img3c = img3.copy()
    gray = cv2.cvtColor(img3,cv2.COLOR_BGR2GRAY)
    ret, thresh = cv2.threshold(gray,0,255,cv2.THRESH_BINARY_INV+cv2.THRESH_OTSU)

    # remove ruídos
    kernel = np.ones((3,3),np.uint8)
    opening = cv2.morphologyEx(thresh,cv2.MORPH_OPEN,kernel, iterations = 0)

    # Fundo da imagem
    sure_bg = cv2.dilate(opening,kernel,iterations=3)

    # Objetos da imagem
    dist_transform = cv2.distanceTransform(opening,cv2.DIST_L2,5)
    ret, sure_fg = cv2.threshold(dist_transform,0.7*dist_transform.max(),255,0)
# Out:
# /content
# /content
# /content
# /content
# /content
# /content
# /content
# /content
# /content
# /content
# /content
# /content
# /content
# /content
# /content
# /content
# /content
# /content
# /content
# /content
# /content
# /content
# /content
# /content
# /content
# /content
# /content
# /content
# /content
# /content
# /content
# /content
# /content
# /content
# /content
# /content
# /content
# /content
# /content
# /content
# /content
# /content
# /content
# /content

# %% [markdown]
# #INTELIGENCIA ARTIFICIAL

# %% [markdown]
# ###Montando Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2
import numpy as np
import os
import pandas as pd
import csv

from matplotlib import pyplot as plt
# %matplotlib inline
from google.colab.patches import cv2_imshow

# %%
#criando duas lista de imagens binarias Maligna e benignas

benignas = os.listdir('/content/drive/My Drive/Colab Notebooks/banco de imagens/bin_B')
malignas = os.listdir('/content/drive/My Drive/Colab Notebooks/banco de imagens/bin_M')
#CRIANDO DUAS LISTAS VAZIAS PARA CRIAR DOIS ARQUIVOS LABEL_B E LABEL_M, ONDE SERÃO ARMAZENADOS
# OS ARRAYS GERADOS PELOS HU MOMENTS
label_B=[]
label_M=[]

#CRIANDO DOIS FOR PARA LER TODAS AS IMAGENS DAS PASTAS BIN_B
for img in benignas:
  src = "/content/drive/My Drive/Colab Notebooks/banco de imagens/bin_B/%s"%(img)
  image = cv2.imread(src)
  gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY )
  array = cv2.HuMoments(cv2.moments(gray)).flatten()
  label_B.append(array) #adicionando lista gerada na lista por nome de label_B

for img in malignas:
  src = "/content/drive/My Drive/Colab Notebooks/banco de imagens/bin_M/%s"%(img)
  image = cv2.imread(src)
  gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY )
  array = cv2.HuMoments(cv2.moments(gray)).flatten()
  label_M.append(array) #adicionando lista gerada na lista por nome de label_M

# %%
#CRIANDO UM DATA SET DAS IMAGENS BIN BENIGNAS com o panda
import pandas as pd

dataset_B = pd.DataFrame(label_B)
dataset_B = pd.DataFrame.to_csv(dataset_B)
dataset_M = pd.DataFrame(label_M)
dataset_M = pd.DataFrame.to_csv(dataset_M)

# %% [markdown]
# ###Salvando labels do Hu Moment

# %%
#salvando arquivo label_B.txt com os arrays das imagens bin benignas

# %cd '/content/drive/My Drive/Colab Notebooks/banco de imagens/label B'
arquivo = open('dataset_B.csv','w')#criando arquivo
arquivo.close()

arquivo = open('dataset_B.csv', 'w')
arquivo.writelines('%s'%(dataset_B))
arquivo.close()

#salvando arquivo label_M.txt com os arrays das imagens bin malignas

# %cd '/content/drive/My Drive/Colab Notebooks/banco de imagens/label M'
arquivo = open('dataset_M.csv', 'w')#criando arquivo
arquivo.close()

arquivo = open('dataset_M.csv', 'w')
arquivo.writelines('%s'%(dataset_M))
arquivo.close()


# %cd '/content/drive/My Drive/Colab Notebooks/banco de imagens'
dataB = pd.read_csv('label B/dataset_B.csv')
dataM = pd.read_csv('label M/dataset_M.csv')
# Out:
# /content/drive/My Drive/Colab Notebooks/banco de imagens/label B
# /content/drive/My Drive/Colab Notebooks/banco de imagens/label M
# /content/drive/My Drive/Colab Notebooks/banco de imagens

# %%
X= dataB[['0','1','2','3','4','5','6']]
y= dataM[['0','1']]

# %%
y
# Out:
#            0             1
# 0   0.000645  1.366492e-08
# 1   0.000646  2.344929e-08
# 2   0.000648  1.447093e-08
# 3   0.000699  6.700885e-08
# 4   0.000735  1.194484e-07
# 5   0.000695  3.317973e-08
# 6   0.000638  2.430561e-09
# 7   0.000643  1.072655e-08
# 8   0.000708  3.058736e-08
# 9   0.000684  4.487152e-08
# 10  0.000666  4.022121e-08
# 11  0.000649  1.859921e-08
# 12  0.000668  3.986230e-09
# 13  0.000640  3.616152e-09
# 14  0.000756  1.362097e-07
# 15  0.000682  7.297232e-08
# 16  0.000730  8.790490e-08
# 17  0.000631  1.593382e-10
# 18  0.000935  4.363672e-07
# 19  0.000736  6.436680e-08

# %%
from sklearn.model_selection import train_test_split

# %%
 X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-f81e051e22d6> in <module>()
# ----> 1 X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py in train_test_split(*arrays, **options)
#    2116         raise TypeError("Invalid parameters passed: %s" % str(options))
#    2117
# -> 2118     arrays = indexable(*arrays)
#    2119
#    2120     n_samples = _num_samples(arrays[0])
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in indexable(*iterables)
#     246     """
#     247     result = [_make_indexable(X) for X in iterables]
# --> 248     check_consistent_length(*result)
#     249     return result
#     250
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     210     if len(uniques) > 1:
# ...

# %%
#QUANTIDADE TREINO BENIGNO
len(X_train)
# Out:
# 29

# %%
#QUANTIDADE PARA TESTE BENIGNO
len(X_test)
# Out:
# 8

# %% [markdown]
# #TESTE

# %%
bancoimagens = os.listdir('Processamento_de_Imagem/Mamografias/')
contador = 0
for n in bancoimagens:

  if n == "mdb010.bmp":
    t= "Processamento_de_Imagem/Mamografias/%s"%(n)
    print('>>>Caminho da imagem Encontrado !!')
    print(t)

    img1 = cv2.imread(t)

    print('>>>Imagem Encontrada, sendo impressa!! %s' %(contador) )
    fig, axes = plt.subplots(1, 2, figsize=(10, 8))
    ax = axes.ravel()

    #Original 1
    ax[0].imshow(img1, cmap='gray')
    ax[0].set_title('original 1')
    ax[0].set_axis_off()

    #Original 2
    ax[1].imshow(img1, cmap='gray')
    ax[1].set_title('original 2')
    ax[1].set_axis_off()
  contador+=1
